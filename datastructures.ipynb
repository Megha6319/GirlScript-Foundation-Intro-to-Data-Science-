# %%
count = 0
while count <= 5:
    print(count)
    count = count + 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Data Structures

# %% [markdown]
# LISTS

# %%
#square brackets to be used
list=['apple','mango','grape']
print(list)
# Out:
# ['apple', 'mango', 'grape']

# %%
type(list)
# Out:
# list

# %%
list=[1, 'megha', 10.0 ]
print(list)
# Out:
# [1, 'megha', 10.0]

# %%
len(list)
# Out:
# 3

# %%
list.append('mom')
print(list)
# Out:
# [1, 'megha', 10.0, 'mom']

# %%
list.insert(2,'dad')
print(list)
# Out:
# [1, 'megha', 'dad', 10.0, 'mom']

# %%
list.remove('megha')
print(list)
# Out:
# [1, 'dad', 10.0, 'mom']

# %%
#slicing
list[2:4]
# Out:
# [10.0, 'mom']

# %%
list.reverse()
print(list)
# Out:
# ['mom', 10.0, 'dad', 1]

# %%
list.index('mom')
# Out:
# 0

# %% [markdown]
# tupple

# %%
#denoted by()
tuple = ('mom', 'dad', 'me')
print(tuple)
# Out:
# ('mom', 'dad', 'me')

# %%
type(tuple)
# Out:
# tuple

# %% [markdown]
# SET

# %%
#IT IS DENOTED BY {}
set = {'doraemon', 'ninja hatori', 'shinchan'}
print(set)
# Out:
# {'shinchan', 'doraemon', 'ninja hatori'}

# %%
type(set)
# Out:
# set

# %% [markdown]
# Dictionary

# %%
dict = {
    'Car' : 'Lamborgini',
    'color' : 'black',
    'dream' : 'hope'
}
print(dict)
# Out:
# {'Car': 'Lamborgini', 'color': 'black', 'dream': 'hope'}

# %%
dict['Car']
# Out:
# 'Lamborgini'

# %%
len('dict')
# Out:
# 4

# %%
type(dict)
# Out:
# dict
