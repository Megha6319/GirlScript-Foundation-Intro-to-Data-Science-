# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('nyc.wether.csv')
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.head(10)
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   1/1/2016           38        23        52                 30.03
# 1   1/2/2016           36        18        46                 30.02
# 2   1/3/2016           40        21        47                 29.86
# 3   1/4/2016           25         9        44                 30.05
# 4   1/5/2016           20        -3        41                 30.57
# 5   1/6/2016           33         4        35                 30.50
# 6   1/7/2016           39        11        33                 30.28
# 7   1/8/2016           39        29        64                 30.20
# 8   1/9/2016           44        38        77                 30.16
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# ...

# %%
df.tail()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df.shape
#total number of rows and columns in data
# Out:
# (31, 11)

# %%
df[2:5]
#2 inlusive , 5exclusive
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 2             277
# 3             345
# 4             333

# %%
df.describe()
#statistical data
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df.Humidity
# Out:
# 0     52
# 1     46
# 2     47
# 3     44
# 4     41
# 5     35
# 6     33
# 7     64
# 8     77
# 9     71
# 10    37
# 11    53
# 12    42
# 13    47
# 14    62
# 15    70
# 16    66
# 17    53
# 18    42
# 19    49
# 20    45
# 21    41
# 22    78
# 23    53
# 24    54
# 25    56
# 26    45
# 27    51
# 28    50
# 29    46
# 30    52
# Name: Humidity, dtype: int64

# %%
df.dtypes
# Out:
# EST                      object
# Temperature               int64
# DewPoint                  int64
# Humidity                  int64
# Sea Level PressureIn    float64
# VisibilityMiles           int64
# WindSpeedMPH            float64
# PrecipitationIn          object
# CloudCover                int64
# Events                   object
# WindDirDegrees            int64
# dtype: object

# %%
df.Temperature.max()
# Out:
# 50

# %%
df.Temperature.min()
# Out:
# 20

# %%
df.Temperature.mean()
# Out:
# 34.67741935483871

# %%
s = pd.Series(list("abcdef") , index=[1,2,3,4,0,2])

# %%
s.loc[0]
# Out:
# 'e'

# %%
s.loc[3]
# Out:
# 'c'

# %%
s.loc[0:1]
# Out:
# Series([], dtype: object)

# %%
df.Temperature == df.Temperature.max()
#comparing value with max ,if its True or false
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# Name: Temperature, dtype: bool

# %%
df1 = df.fillna(0)
df1
#filling missing values
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df1 = df.set_index('EST')
df1.head()
# Out:
#           Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016           38        23        52                 30.03
# 1/2/2016           36        18        46                 30.02
# 1/3/2016           40        21        47                 29.86
# 1/4/2016           25         9        44                 30.05
# 1/5/2016           20        -3        41                 30.57
#
#           VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# EST
# 1/1/2016               10           8.0               0           5    NaN
# 1/2/2016               10           7.0               0           3    NaN
# 1/3/2016               10           8.0               0           1    NaN
# 1/4/2016               10           9.0               0           3    NaN
# 1/5/2016               10           5.0               0           0    NaN
#
#           WindDirDegrees
# EST
# 1/1/2016             281
# 1/2/2016             275
# 1/3/2016             277
# ...

# %%
df1 = df.set_index('DewPoint')
df1.head()
# Out:
#                EST  Temperature  Humidity  Sea Level PressureIn  \
# DewPoint
#  23       1/1/2016           38        52                 30.03
#  18       1/2/2016           36        46                 30.02
#  21       1/3/2016           40        47                 29.86
#  9        1/4/2016           25        44                 30.05
# -3        1/5/2016           20        41                 30.57
#
#           VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# DewPoint
#  23                    10           8.0               0           5    NaN
#  18                    10           7.0               0           3    NaN
#  21                    10           8.0               0           1    NaN
#  9                     10           9.0               0           3    NaN
# -3                     10           5.0               0           0    NaN
#
#           WindDirDegrees
# DewPoint
#  23                  281
#  18                  275
# ...

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#    index       EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0      0  1/1/2016           38        23        52                 30.03
# 1      1  1/2/2016           36        18        46                 30.02
# 2      2  1/3/2016           40        21        47                 29.86
# 3      3  1/4/2016           25         9        44                 30.05
# 4      4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# ...

# %%
# created a copy of dataframe
drop = df.copy()

# droping the rows with NAN values
drop1 = drop.dropna()
drop1
# Out:
#     index        EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8       8   1/9/2016           44        38        77                 30.16
# 15     15  1/16/2016           47        37        70                 29.52
# 16     16  1/17/2016           36        23        66                 29.78
# 17     17  1/18/2016           25         6        53                 29.83
# 22     22  1/23/2016           26        21        78                 29.77
# 23     23  1/24/2016           28        11        53                 29.92
# 26     26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 8                 9           8.0               T           8      Rain
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# ...
